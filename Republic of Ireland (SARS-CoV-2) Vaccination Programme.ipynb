# %% [markdown]
# ### Republic of Ireland (SARS-CoV-2) Vaccination Programme
# ***

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

nAsOf="Thur, 2nd Sept 2021 (Pop. 5,011,500)"
nSingleDose=69.2
nFullyVaccinated=68.0
nVulnerablePopulation=32.0

rcParams["text.color"]="k"
labels="Vulnerable","Vaccinated (inc. Janssen)"
sizes=[nVulnerablePopulation,nFullyVaccinated]
colors=["red","green"]
explode=(0.25,0) # explode 1st slice

plt.title("Republic of Ireland (SARS-CoV-2) Vaccination Programme")
plt.text(1.35,1.02,s=nAsOf,horizontalalignment="center")

plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True,startangle=240)
plt.text(1.1,-1.4,"Single Dose {}%".format(nSingleDose),horizontalalignment="center")
plt.axis('equal')
plt.savefig(fname="../rc/covid-19-ireland/RepublicofIrelandSARS-CoV-2VaccinationProgramme.png")

# %% [markdown]
# [Source (HSE)](https://www.hse.ie/eng/services/news/newsfeatures/covid19-updates/integrated-information-service-vaccination-programme-dashboard.html)

# %% [markdown]
# - Ireland's estimated (usually resident) population at $5,011,500$ (April 2020).

# %% [markdown]
# ![CSO Population](https://github.com/SeanOhAileasa/SeanOhAileasa/blob/master/rc/covid-19-ireland/cso.png?raw=true)

# %% [markdown]
# [Source (CSO)](https://www.cso.ie/en/releasesandpublications/ep/p-pme/populationandmigrationestimatesapril2021/)

# %% [markdown]
# ***
# ### END
